# %% [markdown]
# # Car Price Prediction

# %%
import numpy as np
import pandas as pd
from numpy import random
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car=pd.read_csv(r"F:\Dataset\car_data.csv")

# %%
car=car.rename(columns={"Engine Fuel Type":"Engine_Fuel_Type","Engine HP":"Engine_HP","Engine Cylinders":"Engine_Cylinders","Transmission Type":"Transmission_Type","Number of Doors":"Number_of_Doors","Market Category":"Market_Category","Vehicle Size":"Vehicle_Size","Vehicle Style":"Vehicle_Style","highway MPG":"highway_MPG","city mpg":"city_mpg","natural gas":"natural_gas"})
car
# Out:
#           Make       Model  Year                Engine_Fuel_Type  Engine_HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
car.shape
# Out:
# (11914, 16)

# %%
car.Make.value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
new_car=car[car['Make']=='Volkswagen']
new_car
# Out:
#              Make               Model  Year                Engine_Fuel_Type  \
# 1792   Volkswagen  Beetle Convertible  2014                regular unleaded
# 1793   Volkswagen  Beetle Convertible  2014  premium unleaded (recommended)
# 1794   Volkswagen  Beetle Convertible  2014  premium unleaded (recommended)
# 1795   Volkswagen  Beetle Convertible  2014                regular unleaded
# 1796   Volkswagen  Beetle Convertible  2014                          diesel
# ...           ...                 ...   ...                             ...
# 11188  Volkswagen             Vanagon  1990                regular unleaded
# 11189  Volkswagen             Vanagon  1991                regular unleaded
# 11190  Volkswagen             Vanagon  1991                regular unleaded
# 11191  Volkswagen             Vanagon  1991                regular unleaded
# 11192  Volkswagen             Vanagon  1991                regular unleaded
#
# ...

# %%
new_car.shape
# Out:
# (809, 16)

# %%
new_car.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP              0
# Engine_Cylinders       4
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      224
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
new_car=new_car.dropna()

# %%
new_car.shape
# Out:
# (581, 16)

# %%
new_car=new_car[['Engine_HP','MSRP']]
new_car
# Out:
#        Engine_HP   MSRP
# 1793       210.0  31795
# 1794       210.0  34895
# 1796       140.0  32755
# 1797       210.0  29395
# 1800       210.0  30495
# ...          ...    ...
# 10545      280.0  59745
# 10546      240.0  50245
# 10547      280.0  49495
# 10548      280.0  52795
# 10549      280.0  60195
#
# [581 rows x 2 columns]

# %%
new_car.sample(5)
# Out:
#       Engine_HP   MSRP
# 6020      200.0  23945
# 5632      200.0  26275
# 1866      210.0  31570
# 5618      200.0  28945
# 5652      200.0  24795

# %%
print(new_car['Engine_HP'].dtypes)
print(new_car['MSRP'].dtypes)
# Out:
# float64
# int64

# %%
new_car['MSRP']=new_car['MSRP'].astype(dtype='float64')#converting the MSRP column into float data type

# %%
x=np.array(new_car[['Engine_HP']])
y=np.array(new_car[['MSRP']])
print(x.shape)
print(y.shape)
# Out:
# (581, 1)
# (581, 1)

# %%
x
# Out:
# array([[210.],
#        [210.],
#        [140.],
#        [210.],
#        [210.],
#        [210.],
#        [140.],
#        [210.],
#        [210.],
#        [210.],
#        [140.],
#        [210.],
#        [210.],
#        [210.],
#        [140.],
#        [210.],
#        [140.],
#        [150.],
#        [210.],
#        [210.],
#        [150.],
#        [210.],
#        [210.],
#        [210.],
#        [150.],
#        [150.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [150.],
#        [150.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [150.],
#        [210.],
#        [150.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [210.],
#        [150.],
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=15)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((464, 1), (117, 1), (464, 1), (117, 1))

# %%
from sklearn import linear_model
lin=linear_model.LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lin.predict(x_test)

# %%
y_pred
# Out:
# array([[21204.03299015],
#        [42587.49982751],
#        [29428.44331221],
#        [43080.96444684],
#        [29428.44331221],
#        [29428.44331221],
#        [32718.20744104],
#        [24493.79711897],
#        [29428.44331221],
#        [24493.79711897],
#        [29428.44331221],
#        [31073.32537662],
#        [31073.32537662],
#        [29428.44331221],
#        [29428.44331221],
#        [42587.49982751],
#        [19559.15092573],
#        [29428.44331221],
#        [24493.79711897],
#        [24493.79711897],
#        [31073.32537662],
#        [29428.44331221],
#        [29428.44331221],
#        [31073.32537662],
#        [31073.32537662],
#        [44561.35830481],
#        [44561.35830481],
#        [51634.35118179],
#        [31073.32537662],
#        [32718.20744104],
#        [29428.44331221],
#        [36007.97156986],
#        [21204.03299015],
#        [42587.49982751],
#        [31073.32537662],
#        [24493.79711897],
#        [29428.44331221],
# ...

# %%
#print('R2 score: %.2f' % r2_score(y_test,y_pred))

# %%
R2=lin.score(x_train,y_train)
R2
# Out:
# 0.509298859742835

# %%
Adj_R2=1-(((1-R2)*(464-1))/(464-1-1))
Adj_R2
# Out:
# 0.5082367360626245

# %%
from sklearn import metrics

# %%
mse=metrics.mean_squared_error(y_test,y_pred)
mse
# Out:
# 65565468.84215317

# %%
def car_price(hp):
    result=lin.predict(np.array(hp).reshape(1,-1))
    return(result[0,0])

# %%
car_hp=int(input('enter Volkswagen cars Horse power :'))
print('This Volkswagen price will be: ',int(car_price(car_hp)*69))
# Out:
# enter Volkswagen cars Horse power :32
# This Volkswagen price will be:  123815
